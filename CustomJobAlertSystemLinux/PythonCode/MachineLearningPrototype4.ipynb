# %%
import pandas as pd
import sqlite3
import numpy as np
import time
import os
start_time = time.time()
# read in all the tables into their own dataframes
random_seed = 100
np.random.seed(random_seed)

# Path to your SQLite database
current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
database_path = os.path.join(parent_directory,'DataBase','google_database.db')

# Create a connection to the database
conn = sqlite3.connect(database_path)

# Get a list of all tables in the database
table_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql_query(table_query, conn)

# Create a dictionary to hold dataframes
dataframes = {}

# Load data from each table into a separate DataFrame
for table in tables['name']:
    query = f"SELECT * FROM {table}"
    dataframes[table] = pd.read_sql_query(query, conn)

# Close the connection
conn.close()

# Now, 'dataframes' is a dictionary with table names as keys and corresponding DataFrames as values
# For example, to access a dataframe, use dataframes['table_name']

# %%
# add new column to each dataframe of the job category
for table in tables['name']:
    dataframe = dataframes[table]
    dataframe['Category'] = table[:-5]
    print(dataframe.head())

# Add all the dataframes together into 1 dataframe
job_listings_dataframe = pd.concat([dataframes[table] for table in tables['name']],ignore_index = False)
job_listings_dataframe.head()

job_listings_dataframe = job_listings_dataframe[['JobTitle','Description','Qualifications','Responsibilities','Category']]
job_listings_dataframe = job_listings_dataframe[job_listings_dataframe['Category'] != 'web_developer']
job_listings_dataframe = job_listings_dataframe.sample(frac = 1).reset_index(drop = True)

def remove_whitespace(text):
    return " ".join(text.split())

def clean_data(dataframe):
    # Regex pattern to match various symbols including "•", ",", ".", "\n", "…", "-", and other non-alphanumeric characters
    pattern = r'[•,\n\\…\-\/\(\)\"\!\?\:\;\@\#\$\%\^\&\*\_\+\=\[\]\{\}\|\<\>\`~]'
    for column in dataframe.columns:
        dataframe.loc[:,column] = dataframe[column].astype(str)
        dataframe.loc[:,column] = dataframe[column].str.replace(pattern, ' ', regex = True)
        dataframe.loc[:,column] = dataframe[column].str.lower()
        dataframe.loc[:,column] = dataframe[column].apply(remove_whitespace) 
    return dataframe

job_listings_dataframe.head()
# Out:
#    JobID                                        ListHashing  \
# 0      1  87614021101e011842bb7a94c4fc4f554a7d205bbef5fe...
# 1      2  c8f9d9f9ce663ef31a1bc48fdbc33049ef4220e59f1b74...
# 2      3  c03b0ac2cbde62a6a000e2f9eb747b957ab12650a6a290...
# 3      5  31bff1a9543a6592ab06d020029d633ff696f7ddf7da84...
# 4      6  33cc3f411b485c88b7732c92f91772eba04156bcc51ef3...
#
#                                CompanyTitle  \
# 0                             ClearanceJobs
# 1                                     Adobe
# 2                                      Dice
# 3                                Cosmogence
# 4  Johns Hopkins Applied Physics Laboratory
#
#                                             JobTitle  \
# 0  Software Engineer I - (Onsite) Summer 2024 wit...
# 1                    2024 Intern - Software Engineer
# 2  Senior Lead Software Engineer, Full Stack (Rem...
# 3                     Software Engineer - Internship
# 4  2024 Internship - Software Developer - Tactica...
#
#                                       Qualifications  \
# 0                                               None
# 1  •You are an excellent fit if you have keen eye...
# 2  •Bachelor's Degree •At least 8 years of experi...
# 3  •We are interested in candidates with strong i...
# 4  •Are pursuing a Bachelor's or Master's degree ...
#
#                                     Responsibilities  \
# 0                                               None
# 1  •Working with data scientists, engineers, and ...
# 2  •Provide technical leadership for a portfolio ...
# 3  •The intern will actively contribute to meanin...
# 4  •Your primary responsibility will be to perfor...
#
#                                             Benefits  \
# 0                                               None
# 1  •The U.S. pay range for this position is $38.0...
# 2  •Salaries for part-time roles will be prorated...
# 3  •Practical experience with a wide variety of s...
# 4  •Our employees enjoy generous benefits, includ...
#
#                                          Description DateScraped  \
# 0                                               None        None
# 1  Our Company\n\nChanging the world through digi...        None
# 2  Dice is the leading career destination for tec...        None
# 3  OVERVIEW:\n\nCosmogence invites applications f...        None
# 4  Description\n\nAre you passionate about using ...        None
#
#                Category
# 0  software_development
# 1  software_development
# 2  software_development
# 3  software_development
# 4  software_development
#    JobID                                        ListHashing  \
# 0      1  9f0827b5e114924728bba50b10f58964c83ab211bb51a2...
# 1      2  f51150f51a1b908d053d3bd0dd2fd6ddc4bf5734b1f3b2...
# 2      3  4d3a66f515e297e9db0243d4bb44d112f02c8ebabc44dc...
# 3      4  cd84e16448f8b7435243b77978286d85574f2bbb258ab5...
# 4      5  d0ffb90e2f161822d46158c5e8da35cbeadbdc2aaffef7...
#
#          CompanyTitle                                           JobTitle  \
# 0               WayUp  Experian, Data Science - Analytics & Generativ...
# 1              Oracle                             UX Data Science Intern
# 2             Atmosfy                                Data Science Intern
# 3  Trane Technologies               2024 Analytics & Data Science Intern
# 4     Lockheed Martin                            Data Scientist - Intern
#
#                                       Qualifications  \
# 0  •The candidate should have played with applica...
# 1  •We are seeking to grow the data science capab...
# 2                                               None
# 3  •We are looking for performance-driven, innova...
# 4  •Pursuing bachelor’s degree in quantitative ma...
#
#                                     Responsibilities  \
# 0  •The Data Science Intern will play a critical ...
# 1  •Through hands-on participation in group proje...
# 2  •This position will work closely with Growth L...
# 3  •Collaborate with others on the analytics team...
# 4  •In this role, you will support internal auton...
#
#                                             Benefits  \
# 0  •This position can be 100% remote •Volunteer T...
# 1                                               None
# 2                    •Compensation: $40-$50 per hour
# 3  •Base Pay: $21.00 – $28.50 per hour •Disclaime...
# 4  •Our flexible schedules, competitive pay, and ...
#
#                                          Description DateScraped      Category
# 0  This role is with Experian. WayUp is partnerin...        None  data_science
# 1  Overview\n\nIf you're a creative person who lo...        None  data_science
# 2  Who are you?\n\nSimply put, you're a highly an...        None  data_science
# 3  At Trane TechnologiesTM and through our busine...        None  data_science
# 4  Description:By bringing together people that u...        None  data_science
#    JobID                                        ListHashing  \
# 0      1  638d82c29493eb0d832fc1e24ea75fac7fb0ccadbf972d...
# 1      2  005f9e603289a93ca3d10d9b5896819ca286feb44c0f91...
# 2      3  6abc549a96bb9e0b721cf99a5a3c7a6a0159a46c2cb20e...
# 3      4  ba5ccc5523177daadeac12191666fe1f928911ea3a0024...
# 4      5  1547bc975805203019fab15499f728eb56068bde0c71ca...
#
#                  CompanyTitle  \
# 0                    Unilever
# 1                    Unilever
# 2                     Year Up
# 3                   Honeywell
# 4  Federal Reserve Bank (FRB)
#
#                                             JobTitle  \
# 0                      Information Technology Intern
# 1  2024 Summer Internship Information Technology-...
# 2       Entry-level Information Technology (IT) Role
# 3  Information Systems, IT, Cyber Engineer & Data...
# 4  Summer 2024 Intern - Information Technology Se...
#
#                                       Qualifications  \
# 0  •All you need is a computer or mobile device w...
# 1  •You are someone who likes to control their ow...
# 2  •A high school graduate or GED recipient •Elig...
# 3  •Must be pursuing a Bachelor’s or Master’s deg...
# 4  •Exposure to business process tools, low code ...
#
#                                     Responsibilities  \
# 0  •You will have an opportunity to truly lead a ...
# 1  •You will have an opportunity to truly lead a ...
# 2                                               None
# 3           •You’ll help solve real-world challenges
# 4  •The intern will contribute to product design ...
#
#                                             Benefits  \
# 0  •You will have the opportunity to work with bo...
# 1                                               None
# 2  •Year Up participants also receive an educatio...
# 3                                               None
# 4  •Flexible hours •Professional development oppo...
#
#                                          Description DateScraped  \
# 0  This unique programme is designed to develop U...        None
# 1  Our Future Leaders Programme will ignite the l...        None
# 2  Year Up is a one-year or less, intensive job t...        None
# 3  Join a team recognized for leadership, innovat...        None
# 4  CompanyFederal Reserve Bank of Dallas\n\nWe ar...        None
#
#                  Category
# 0  information_technology
# 1  information_technology
# 2  information_technology
# 3  information_technology
# 4  information_technology
#    JobID                                        ListHashing  \
# 0      1  a18df77fc281860079386f14f354de401d6d914469f2d5...
# 1      2  1eb4c09eec9dbdccd353fe463d63e519e82e077d5e481f...
# 2      3  f85691d8303ada83fdd7999d29bef270bcfeb03761040a...
# 3      4  39db6e9dd3b69a9f31fe09b64a1566db874aaba54effee...
# 4      5  56dd462b970d33a5ccc81961f43a2db6c74ca68bc89dcf...
#
#                   CompanyTitle                                JobTitle  \
# 0                  BAE Systems                    Cybersecurity intern
# 1                        Xylem                  Intern - Cybersecurity
# 2  Department of Defense (DoD)             Department of Defense (DoD)
# 3              Lockheed Martin  Cybersecurity System Engineer (Intern)
# 4                   Graco Inc.                    Cybersecurity Intern
#
#                                       Qualifications  \
# 0  •Must be currently enrolled in a computer scie...
# 1  •Currently enrolled in a 4-year degree program...
# 2                                               None
# 3  •Basic skill requirements will include knowled...
# 4                                               None
#
#                                     Responsibilities  \
# 0                                               None
# 1  •The duties of this internship will range acro...
# 2                                               None
# 3  •Perform various cybersecurity systems enginee...
# 4                                               None
#
#                                             Benefits  \
# 0  •Internships are paid and internships often le...
# 1  •The average hourly rate for an intern is betw...
# 2  •Get a head start on your career by taking adv...
# 3  •These condensed schedules provide employees w...
# 4                                               None
#
#                                          Description DateScraped  \
# 0  JOB DESCRIPTION\n\nJob Description...\n\nBAE S...        None
# 1  We're Hiring for a Cybersecurity Intern!\n\nTh...        None
# 2  STUDENT OPPORTUNITIES\n\nGet a head start on y...        None
# 3  Description:At Lockheed Martin Rotary and Miss...        None
# 4                                               None        None
#
#         Category
# 0  cybersecurity
# 1  cybersecurity
# 2  cybersecurity
# 3  cybersecurity
# 4  cybersecurity
#    JobID                                        ListHashing  \
# 0      1  bcb167182dc686e895beff543f72f5b9465ad7b009f314...
# 1      2  253417f2a31d61aca46e2e67fb5ac3ee8aceefabf36855...
# 2      3  f45961e7a7b5cb137aadac5881455772c969ddcab18e0a...
# 3      4  432831cdb436d5dfd14ff3783441787097db4bb7de7955...
# 4      5  c8f9d9f9ce663ef31a1bc48fdbc33049ef4220e59f1b74...
#
#                CompanyTitle                         JobTitle  \
# 0                   MindPal    Python Developer (internship)
# 1  Consumer Focus Marketing           Web Development Intern
# 2                Graco Inc.             Web Developer Intern
# 3               iserviceweb        Back End Developer Intern
# 4                     Adobe  2024 Intern - Software Engineer
#
#                                       Qualifications  \
# 0  •Enthusiasm for learning and an open mind •Kno...
# 1  •Proficiency with HTML5/CSS3 •Prior experience...
# 2  •Knowledge or demonstrated coursework developi...
# 3  •Proficiency in Back-End Web Development, Soft...
# 4  •You are an excellent fit if you have keen eye...
#
#                                     Responsibilities  \
# 0  •Maintain and develop the backend of a recruit...
# 1  •The Web Developer Intern will work closely wi...
# 2  •During the internship, you will work on proje...
# 3  •Join us as a remote Back End Developer intern...
# 4  •Working with data scientists, engineers, and ...
#
#                                             Benefits  \
# 0                                               None
# 1  •Pay: $15.00 per hour •Expected hours: 10 – 20...
# 2  •Graco offers attractive compensation, benefit...
# 3  •Compensation: This is a remote unpaid interns...
# 4  •The U.S. pay range for this position is $38.0...
#
#                                          Description DateScraped  \
# 0  Summer Internship Opportunity - Python Develop...        None
# 1  Consumer Focus™ Marketing is searching for a W...        None
# 2  Graco manufactures and markets premium equipme...        None
# 3  Company Description:\n\nDiscover iServiceWeb: ...        None
# 4  Our Company\n\nChanging the world through digi...        None
#
#         Category
# 0  web_developer
# 1  web_developer
# 2  web_developer
# 3  web_developer
# 4  web_developer
#    JobID                                        ListHashing  \
# 0      1  e493c8c19499f816ab9e328e800442baac957af1bd13db...
# 1      2  1eff466e2dc34564cc154ee30e733839d381de0e349540...
# 2      3  5f4176cda4d0efd1e65c10c01f1758d3f7be4c9544f4b4...
# 3      4  a0996bbdda1ba401aa232a30a080ee158909fbe7ebb4be...
# 4      5  da5d126facb8af53a0e28e5f2645b4dc9e27736417c847...
#
#         CompanyTitle                                           JobTitle  \
# 0            Nutanix  Software Engineering Intern (Undergraduates Only)
# 1          Confluent                Trust & Security Engineering Intern
# 2  Change Healthcare                              AI Engineering Intern
# 3            Peraton        Jr Systems Engineer with Security Clearance
# 4     Black & Veatch                       OSP Field Engineering Intern
#
#                                       Qualifications  \
# 0  •*Software Engineer Intern: Summer 2024 - Bach...
# 1  •Currently pursuing a Bachelor's, Master's, or...
# 2  •Curious and high energy •Ability to thrive in...
# 3  •Bachelor of Science (STEM) degree in Computer...
# 4  •MDU Fielding Experience, excellent people ski...
#
#                                     Responsibilities  \
# 0  •Collaborate with technical staff/leaders to d...
# 1                                               None
# 2  •As a full-time, paid intern, you will be enga...
# 3  •Responsibilities The Nuclear Safety Cross Che...
# 4  •This position requires frequent travel to Den...
#
#                                             Benefits  \
# 0  •Mentorship and support from your manager and ...
# 1                                               None
# 2  •The base pay range for Colorado residents is ...
# 3  •Target Salary Range $66,000 - $106,000 •This ...
# 4  •Full time/Part time : Full-Time •Salary Plan ...
#
#                                          Description DateScraped  \
# 0  • *Software Engineer Intern: Summer 2024 - Bac...  2024-01-05
# 1  Confluent is pioneering a fundamentally new ca...  2024-01-05
# 2  AI Engineering Intern - Summer 2022\n\nPOSITIO...  2024-01-05
# 3  Peraton Overview Peraton drives missions of co...  2024-01-05
# 4  OSP Field Engineering Intern - Denver, CO\n\nD...  2024-01-05
#
#          Category
# 0  recent_job_lis
# 1  recent_job_lis
# 2  recent_job_lis
# 3  recent_job_lis
# 4  recent_job_lis
#                                           JobTitle  \
# 0                   Data Science MS/PhD Internship
# 1                             Cybersecurity Intern
# 2                            Cyber Security Intern
# 3  Software Development Intern (M&S) - Summer 2024
# 4                  Information Technologies Intern
#
#                                          Description  \
# 0  Who are we and why should you join us?\n\nBett...
# 1  Overview:\n\nS2 Global, an OSI Systems Company...
# 2  Why Badger Meter?\n\nBadger Meter is a leading...
# 3  Tyler Technologies is looking for Software Dev...
# 4  We Care. We Deliver. Our purpose is to create ...
#
#                                       Qualifications  \
# 0  •The ideal candidate would have experience wit...
# 1  •Familiarity with security standards and frame...
# 2  •Strong interpersonal, communication, and docu...
# 3  •Pursuing a bachelor's degree in Computer Scie...
# 4  •Hands on experience with business processes •...
#
#                                     Responsibilities                Category
# 0  •You will use data to drive insight into the p...            data_science
# 1  •Focused on Operations, Integration and Traini...           cybersecurity
# 2  •The Cyber Security Analyst Intern will assist...           cybersecurity
# 3  •The Software Development Intern will experien...    software_development
# 4  •Assisting in preparing presentations •Analyzi...  information_technology

# %%
# Assuming your DataFrame is named job_listings_dataframe
if 'Category' in job_listings_dataframe.columns:
    # Keep only the rows where 'Category' is not 'recent_job_lis'
    job_listings_dataframe = job_listings_dataframe[job_listings_dataframe['Category'] != 'recent_job_lis']

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

np.random.seed(random_seed)
X_train, X_test_and_val, y_train, y_test_and_val = train_test_split(job_listings_dataframe['JobTitle'],
                                                                    job_listings_dataframe['Category'],
                                                                    test_size = 0.3,
                                                                    stratify=job_listings_dataframe['Category'])

X_test, X_val, y_test, y_val = train_test_split(X_test_and_val, y_test_and_val, test_size = 0.5, stratify = y_test_and_val)


random_forest_pipeline = Pipeline([('tfidf', TfidfVectorizer(stop_words='english')),
                                   ('classifier', RandomForestClassifier(n_jobs=-4))])

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
y_val_encoded = label_encoder.transform(y_val)

random_forest_pipeline.fit(X_train, y_train_encoded)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(stop_words='english')),
#                 ('classifier', RandomForestClassifier(n_jobs=-4))])

# %%
untuned_predictions = []

# %%
random_forest_test_predictions = random_forest_pipeline.predict(X_test)
print(classification_report(y_test_encoded,random_forest_test_predictions))
print(accuracy_score(y_test_encoded, random_forest_test_predictions))
untuned_predictions.append(classification_report(y_test_encoded,random_forest_test_predictions))
untuned_predictions.append(accuracy_score(y_test_encoded, random_forest_test_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91        50
#            1       0.98      1.00      0.99        79
#            2       0.91      0.95      0.93        73
#            3       0.97      0.97      0.97        70
#
#     accuracy                           0.95       272
#    macro avg       0.95      0.94      0.95       272
# weighted avg       0.95      0.95      0.95       272
#
# 0.9522058823529411

# %%
random_forest_val_predictions = random_forest_pipeline.predict(X_val)
print(classification_report(y_val_encoded,random_forest_val_predictions))
print(accuracy_score(y_val_encoded, random_forest_val_predictions))
untuned_predictions.append(classification_report(y_val_encoded,random_forest_val_predictions))
untuned_predictions.append(accuracy_score(y_val_encoded, random_forest_val_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        50
#            1       0.96      0.99      0.97        79
#            2       0.91      0.86      0.89        74
#            3       0.93      0.96      0.94        69
#
#     accuracy                           0.93       272
#    macro avg       0.93      0.93      0.93       272
# weighted avg       0.93      0.93      0.93       272
#
# 0.9301470588235294

# %%
prediction = random_forest_pipeline.predict(["software engineer"])
print(prediction)
print(label_encoder.inverse_transform(prediction))
# Out:
# [3]
# ['software_development']

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

np.random.seed(random_seed)

X_train, X_test_and_val, y_train, y_test_and_val = train_test_split(job_listings_dataframe['JobTitle'],
                                                                    job_listings_dataframe['Category'],
                                                                    test_size = 0.3,
                                                                    stratify=job_listings_dataframe['Category'])

X_test, X_val, y_test, y_val = train_test_split(X_test_and_val, y_test_and_val, test_size = 0.5, stratify = y_test_and_val)

# Define the parameter grid for RandomForestClassifier
random_forest_param_grid = {
    'n_estimators': [100, 200, 300, 500, 700, 1000],
    'max_depth': [5, 10, 20, 30, 50, 70, None],
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 4, 6, 8],
    'max_features': ['auto', 'sqrt', 'log2'],
    'bootstrap': [True, False],
    'criterion': ['gini', 'entropy']
}


random_forest_grid_search = RandomizedSearchCV(RandomForestClassifier(),
                                                param_distributions = random_forest_param_grid,
                                                n_iter = 500,
                                                cv = 5,
                                                scoring='f1_weighted',
                                                n_jobs = -4)


random_forest_pipeline = Pipeline([('tfidf', TfidfVectorizer(stop_words='english')),
                                   ('classifier', random_forest_grid_search)])

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
y_val_encoded = label_encoder.transform(y_val)

random_forest_pipeline.fit(X_train, y_train_encoded)
# Out:
# C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 905 fits failed out of a total of 2500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 651 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\utils\_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 254 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\utils\_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [0.68114111 0.88290963 0.93203338 0.9287027  0.66030988 0.91827545
#  0.65026685        nan 0.93258103 0.92715675 0.92243174 0.92081168
#  0.67935314 0.62764756 0.93029476 0.92065097        nan 0.93037305
#         nan 0.92563523 0.65885598 0.61387298        nan        nan
#  0.65379058        nan        nan        nan 0.86439774 0.9301452
#  0.92716311 0.65115554 0.90298107        nan 0.93258774 0.89486795
#         nan 0.93028458        nan        nan        nan 0.67138987
#  0.67235712        nan        nan 0.93190583 0.89090613 0.91420999
#  0.93040299 0.8672635  0.92847821 0.92294702 0.92369728        nan
#         nan 0.92484652        nan 0.91161485 0.90832619 0.91240309
#  0.65765254        nan 0.92537961        nan 0.84182852 0.92145513
#  0.92230859        nan 0.65493122 0.66313772        nan 0.89068598
#  0.86981782 0.90421992 0.89334531 0.92797183 0.60807083        nan
#  0.92883802 0.93186453 0.92150497 0.89837146        nan 0.6654295
#  0.92875548        nan 0.79085434        nan 0.68082401        nan
#  0.90028716 0.66492969 0.91419819 0.90226952 0.93007044 0.93030157
#  0.86755242 0.67075236 0.92312671 0.92545352        nan        nan
#  0.84086703 0.66413657        nan        nan 0.93022593 0.92707101
#  0.92708016 0.85966192        nan        nan 0.92476734 0.65778886
#  0.61081699        nan        nan 0.86640329        nan 0.89026727
#  0.92066737 0.92468003 0.82967658 0.65957981 0.6418393  0.62498766
#         nan 0.93114824        nan        nan        nan        nan
#  0.86228961 0.92877082        nan        nan        nan        nan
#         nan 0.92792694        nan 0.92618486        nan 0.63189396
#         nan 0.92480571 0.92106372        nan 0.92948859        nan
#         nan        nan        nan        nan        nan        nan
#  0.93185531 0.90248043 0.54112059        nan 0.84226755 0.65850285
#  0.88721697        nan 0.93114824 0.93512372        nan        nan
#         nan 0.92716804 0.61674836 0.93185347 0.64009924        nan
#         nan        nan        nan 0.93182745 0.88289426 0.93025659
#  0.65541125 0.90512907        nan 0.91397817        nan        nan
#         nan 0.90321847        nan        nan 0.91009508        nan
#  0.93424148 0.54393297        nan 0.91174726 0.70825082        nan
#  0.61526994        nan 0.92733077 0.92642012 0.92632658 0.63532225
#  0.63843937        nan 0.92532495 0.5891466  0.54170689 0.93424002
#         nan 0.66054415 0.67646731 0.84638867 0.91906482 0.6510666
#  0.91249393        nan 0.84929733 0.90569077        nan        nan
#         nan 0.89773632 0.92953952 0.92567782 0.93016992        nan
#  0.92636283 0.92295528 0.86162121 0.9256376         nan 0.86358531
#         nan 0.85855186 0.55416203 0.64171591 0.91980378        nan
#  0.93169712        nan        nan        nan 0.78682573 0.65199356
#  0.67257154 0.71048904 0.93269062        nan        nan        nan
#         nan 0.65900537 0.93123771        nan        nan 0.93008396
#         nan 0.91875377 0.93038994        nan 0.82499309 0.51493015
#  0.89528542        nan 0.92155122        nan 0.56250632 0.67036222
#  0.85609089 0.93109448 0.924629          nan 0.83698125        nan
#         nan 0.91635411 0.59361543 0.91328804 0.86856656        nan
#  0.92272082        nan        nan 0.85713746        nan        nan
#  0.62866598        nan 0.91139663 0.6355351         nan 0.82847306
#         nan        nan        nan        nan 0.91472612        nan
#         nan 0.93036671 0.92151058        nan 0.85898452 0.90993401
#         nan        nan 0.87939144 0.83787737        nan 0.92714764
#         nan        nan 0.65227015 0.72028566        nan 0.64825126
#  0.91751191 0.72486261 0.83983984 0.62939417        nan 0.73385608
#  0.92885672        nan 0.62784099 0.90692987        nan 0.92954114
#  0.58235902        nan        nan 0.63954022 0.93349387        nan
#         nan 0.92153258 0.67373924        nan 0.93035739 0.66073643
#         nan 0.9182964  0.75326237 0.92856358        nan 0.63914434
#  0.93275006 0.92307279 0.65440675 0.85985245        nan 0.83213844
#  0.63365106 0.91168016        nan        nan 0.6706131  0.66334968
#  0.92239402 0.93018984 0.93034407 0.67642623 0.65723938        nan
#         nan 0.91324883 0.72316365 0.65016112        nan 0.905872
#  0.92809742        nan 0.93192626 0.63230287 0.67354283        nan
#         nan 0.9173012  0.62681556 0.92552579 0.63475107 0.90982617
#  0.63531803        nan        nan        nan        nan 0.90512299
#  0.91832952        nan 0.79645528 0.92863921 0.63273879 0.92706586
#  0.69725299 0.6031516  0.67232115 0.66323314 0.92298635        nan
#         nan 0.92316502        nan 0.805761          nan 0.8951353
#  0.86605188        nan 0.92689864 0.9302136         nan 0.93250397
#  0.84308495        nan 0.91241665        nan 0.63591204 0.65936136
#  0.91489917 0.61395895 0.9295721         nan 0.93010636 0.65229051
#         nan        nan 0.90087427        nan 0.52667708 0.76924903
#         nan 0.83602853 0.92539502        nan 0.65139929 0.69956617
#  0.92562262 0.64651226 0.84681471        nan        nan 0.9115391
#  0.86165991 0.59775346        nan 0.60621447        nan        nan
#  0.67378789        nan 0.63289621 0.58974096        nan        nan
#  0.93330236 0.52548854 0.65969069 0.92553132 0.83649109        nan
#  0.65252863 0.66983188 0.85466047 0.9335078  0.92929568 0.9285986
#  0.92687672        nan        nan 0.84919856 0.92453901 0.92284635
#         nan        nan 0.92122872        nan 0.92808814 0.91742987
#  0.92784073 0.87760713        nan 0.62994759        nan        nan
#  0.82757771 0.62955478 0.92069651 0.78189502        nan 0.89742528
#  0.86220265 0.92225471        nan        nan 0.91196114 0.66468621
#  0.89553352        nan]
#   warnings.warn(
# Pipeline(steps=[('tfidf', TfidfVectorizer(stop_words='english')),
#                 ('classifier',
#                  RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                                     n_iter=500, n_jobs=-4,
#                                     param_distributions={'bootstrap': [True,
#                                                                        False],
#                                                          'criterion': ['gini',
#                                                                        'entropy'],
#                                                          'max_depth': [5, 10,
#                                                                        20, 30,
#                                                                        50, 70,
#                                                                        None],
#                                                          'max_features': ['auto',
#                                                                           'sqrt',
#                                                                           'log2'],
#                                                          'min_samples_leaf': [1,
#                                                                               2,
#                                                                               4,
#                                                                               6,
#                                                                               8],
#                                                          'min_samples_split': [2,
#                                                                                5,
#                                                                                10,
#                                                                                15,
#                                                                                20],
#                                                          'n_estimators': [100,
#                                                                           200,
#                                                                           300,
#                                                                           500,
#                                                                           700,
#                                                                           1000]},
#                                     scoring='f1_weighted'))])

# %%
random_forest_test_predictions = random_forest_pipeline.predict(X_test)
print(classification_report(y_test_encoded,random_forest_test_predictions))
print(accuracy_score(y_test_encoded, random_forest_test_predictions))
print(untuned_predictions[0])
print(untuned_predictions[1])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93        50
#            1       0.99      1.00      0.99        79
#            2       0.92      0.95      0.93        73
#            3       0.97      0.97      0.97        70
#
#     accuracy                           0.96       272
#    macro avg       0.96      0.95      0.96       272
# weighted avg       0.96      0.96      0.96       272
#
# 0.9595588235294118
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91        50
#            1       0.98      1.00      0.99        79
#            2       0.91      0.95      0.93        73
#            3       0.97      0.97      0.97        70
#
#     accuracy                           0.95       272
#    macro avg       0.95      0.94      0.95       272
# weighted avg       0.95      0.95      0.95       272
#
# 0.9522058823529411

# %%
random_forest_val_predictions = random_forest_pipeline.predict(X_val)
print(classification_report(y_val_encoded,random_forest_val_predictions))
print(accuracy_score(y_val_encoded, random_forest_val_predictions))
print(untuned_predictions[2])
print(untuned_predictions[3])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        50
#            1       0.96      0.99      0.97        79
#            2       0.93      0.86      0.90        74
#            3       0.93      0.97      0.95        69
#
#     accuracy                           0.93       272
#    macro avg       0.93      0.93      0.93       272
# weighted avg       0.93      0.93      0.93       272
#
# 0.9338235294117647
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        50
#            1       0.96      0.99      0.97        79
#            2       0.91      0.86      0.89        74
#            3       0.93      0.96      0.94        69
#
#     accuracy                           0.93       272
#    macro avg       0.93      0.93      0.93       272
# weighted avg       0.93      0.93      0.93       272
#
# 0.9301470588235294

# %%
# Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(job_listings_dataframe['Category'])

# Fit the pipeline on the full dataset
random_forest_pipeline.fit(job_listings_dataframe['JobTitle'], y_encoded)

# At this point, your pipeline is trained on the entire dataset
# Out:
# C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 875 fits failed out of a total of 2500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 340 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\utils\_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 535 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\utils\_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\anaxi\miniconda3\envs\webscraping\Lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [0.49311397 0.84930167 0.68723652 0.93555697 0.93718538 0.92461517
#         nan 0.92685426        nan        nan 0.81524446        nan
#         nan        nan 0.88467287 0.92758877 0.67476342        nan
#  0.92861368 0.93200153 0.47761148        nan 0.93138616        nan
#  0.71034765 0.64763198 0.68294239        nan 0.93499008 0.87916753
#  0.93209756        nan 0.63753124 0.92993323 0.91486638 0.62935683
#  0.92281826        nan 0.92981221 0.92691117 0.93385897        nan
#  0.63713914        nan        nan        nan 0.93389309        nan
#  0.9291879         nan 0.93169619        nan 0.66915535 0.93191263
#         nan 0.74947594        nan        nan 0.92906714 0.6614521
#         nan 0.65453271 0.66495796 0.93142396        nan 0.93439324
#  0.93210412 0.9275036  0.9201407  0.93599683        nan 0.92756273
#         nan        nan 0.89607029 0.59862711 0.93500714 0.92691489
#         nan 0.87532853 0.93493933 0.57650768 0.56605571 0.8729398
#  0.50023207 0.89871757        nan        nan        nan        nan
#         nan 0.6526799  0.93370784 0.90227646        nan 0.9354152
#         nan 0.48683049 0.65178659 0.65995695 0.92625996 0.8965657
#  0.93391285 0.93431415        nan        nan 0.92922287 0.65240813
#         nan 0.93385232 0.66911875 0.53663145 0.93051752        nan
#  0.93216401        nan 0.91846193 0.93380016        nan        nan
#         nan 0.65546811 0.93306338 0.63376752 0.92228408        nan
#  0.92923841 0.86642655 0.93097409 0.5995665         nan 0.93544358
#  0.48271874 0.78472808 0.56751607 0.8823201         nan 0.65687272
#  0.92869185 0.54500298 0.50645778        nan        nan        nan
#  0.93770942 0.85227183 0.93033023 0.90682976 0.9338581         nan
#  0.6303825  0.72621016 0.91775468 0.72235235 0.60779073        nan
#         nan 0.92004468 0.89386824        nan 0.93599572 0.92702087
#         nan 0.9195798         nan 0.86934425 0.91066856 0.92124707
#  0.91588286        nan 0.92121472 0.93310134 0.89272695        nan
#  0.91998498        nan 0.66201974        nan 0.91729743 0.66133692
#  0.87861329 0.70327539        nan        nan        nan        nan
#  0.92635863        nan 0.56058461 0.87849483 0.9149492  0.9361079
#  0.93496771 0.65890689        nan 0.90064405 0.93333593 0.92114307
#  0.90790137 0.55954672 0.93451656 0.93217406 0.5589091  0.92514926
#  0.9333037         nan 0.92866872 0.93594441 0.92296826        nan
#         nan 0.91890158 0.9315637         nan        nan 0.65808127
#  0.9165678         nan 0.61884671 0.88714302 0.927955   0.87208012
#         nan 0.89752767 0.92228627 0.93331703        nan 0.93246563
#  0.93602372        nan 0.93713735 0.91899338 0.93448771 0.63764563
#         nan 0.74811366        nan 0.69357291 0.90403754 0.92964821
#  0.58323401 0.91824446 0.93050476 0.66223331        nan 0.91681093
#         nan        nan 0.59793742        nan        nan 0.93441717
#  0.93141519 0.93206429 0.51526652        nan 0.65586147 0.92174771
#         nan 0.93094566 0.67838912 0.47546854 0.89331748 0.93449152
#  0.92064712 0.71349732 0.71528276        nan        nan 0.88366966
#  0.89892935 0.93429011 0.69037967        nan 0.86933038        nan
#         nan 0.63257751        nan        nan 0.93212847 0.93388076
#         nan        nan        nan 0.91635831 0.68741734        nan
#  0.71498896        nan 0.93442829 0.89911753        nan        nan
#         nan        nan 0.92853824 0.93278005        nan 0.93428138
#  0.68628616        nan        nan 0.92909828 0.63630421        nan
#  0.68324413 0.92571961        nan 0.88434912 0.93655663 0.92928587
#  0.92627421 0.66544136 0.92451553 0.9235583  0.93532739        nan
#         nan        nan 0.89104552        nan        nan 0.93434942
#  0.8675052  0.93558014        nan 0.66546561        nan        nan
#  0.4182943         nan 0.909321          nan 0.93152727 0.92003433
#  0.9235721  0.91669197        nan        nan        nan 0.53843784
#  0.65519451 0.92237632 0.72268591 0.9138657  0.66026927        nan
#  0.92712707 0.82514791 0.4987338         nan        nan        nan
#  0.59261861        nan 0.65882228 0.91912072 0.69285172        nan
#  0.93077206 0.60938288 0.88831004 0.93680395        nan        nan
#  0.65739707 0.57073439 0.93498916 0.93209168 0.93657025 0.56761273
#         nan        nan        nan 0.88498564 0.92422726        nan
#  0.93497465 0.93362037 0.72527371 0.64536988        nan        nan
#  0.66678864        nan        nan 0.93776173        nan        nan
#         nan 0.89301941 0.93034244 0.93499774        nan        nan
#         nan        nan 0.93253629 0.74082509        nan        nan
#  0.92126462 0.89575195 0.91772391 0.93331821 0.86759618        nan
#         nan 0.88374103 0.9262278         nan        nan 0.89197511
#  0.60063267 0.68506198        nan 0.93311398 0.93327482 0.66114406
#         nan 0.93342092        nan        nan 0.90286928 0.64227601
#  0.92630017 0.93092798        nan 0.9212808  0.93440095        nan
#  0.88619691        nan        nan        nan 0.92339621 0.92293552
#  0.66242619        nan 0.90048739 0.93152616        nan 0.73457424
#         nan        nan 0.92749038 0.91813953 0.93265953 0.93725053
#  0.65161555 0.60152679        nan        nan        nan 0.62005787
#         nan        nan 0.87461356 0.92700975 0.52100757 0.65729788
#         nan 0.93268754 0.92959194 0.93284623 0.42419716        nan
#  0.59322476        nan 0.93383564 0.93448857        nan 0.92462191
#  0.63324476 0.65456653 0.93220537 0.92511972        nan 0.70802933
#         nan 0.65686708        nan 0.92387445 0.6349112         nan
#  0.93142974 0.93380985 0.91619073 0.93335859 0.9220024         nan
#  0.92410018        nan 0.93436388 0.63242641 0.63494507 0.92604219
#  0.93103815        nan]
#   warnings.warn(
# Pipeline(steps=[('tfidf', TfidfVectorizer(stop_words='english')),
#                 ('classifier',
#                  RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                                     n_iter=500, n_jobs=-4,
#                                     param_distributions={'bootstrap': [True,
#                                                                        False],
#                                                          'criterion': ['gini',
#                                                                        'entropy'],
#                                                          'max_depth': [5, 10,
#                                                                        20, 30,
#                                                                        50, 70,
#                                                                        None],
#                                                          'max_features': ['auto',
#                                                                           'sqrt',
#                                                                           'log2'],
#                                                          'min_samples_leaf': [1,
#                                                                               2,
#                                                                               4,
#                                                                               6,
#                                                                               8],
#                                                          'min_samples_split': [2,
#                                                                                5,
#                                                                                10,
#                                                                                15,
#                                                                                20],
#                                                          'n_estimators': [100,
#                                                                           200,
#                                                                           300,
#                                                                           500,
#                                                                           700,
#                                                                           1000]},
#                                     scoring='f1_weighted'))])

# %%
from joblib import dump

# save model and encoder to file
dump(random_forest_pipeline, 'random_forest_model.joblib')
dump(label_encoder, 'random_forest_encoder.joblib')
end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Execution time: 148.55682563781738 seconds
